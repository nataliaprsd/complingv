# %%
# !wget http://hca.gilead.org.il/vt/li_merma.txt
# Out:
# --2024-12-28 18:11:09--  http://hca.gilead.org.il/vt/li_merma.txt
# Resolving hca.gilead.org.il (hca.gilead.org.il)... 152.19.134.41
# Connecting to hca.gilead.org.il (hca.gilead.org.il)|152.19.134.41|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50061 (49K) [text/plain]
# Saving to: ‘li_merma.txt.1’
#
# li_merma.txt.1      100%[===================>]  48.89K  --.-KB/s    in 0.05s
#
# 2024-12-28 18:11:09 (912 KB/s) - ‘li_merma.txt.1’ saved [50061/50061]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'li_merma.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[500:1000]
# Out:
# 'above. there dwell the sea king\nand his subjects. we must not imagine that there is nothing at the\nbottom of the sea but bare yellow sand. no, indeed; the most\nsingular flowers and plants grow there; the leaves and stems of\nwhich are so pliant, that the slightest agitation of the water\ncauses them to stir as if they had life. fishes, both large and small,\nglide between the branches, as birds fly among the trees here upon\nland. in the deepest spot of all, stands the castle of the sea king.\nits wa'

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[500:1000]
# Out:
# 'well the sea king\nand his subjects. we must not imagine that there is nothing at the\nbottom of the sea but bare yellow sand. no indeed the most\nsingular flowers and plants grow there the leaves and stems of\nwhich are so pliant that the slightest agitation of the water\ncauses them to stir as if they had life. fishes both large and small\nglide between the branches as birds fly among the trees here upon\nland. in the deepest spot of all stands the castle of the sea king.\nits walls are built of coral'

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# [' there dwell the sea king\nand his subjects',
#  ' we must not imagine that there is nothing at the\nbottom of the sea but bare yellow sand']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['no',
#  'indeed',
#  'the',
#  'most',
#  'singular',
#  'flowers',
#  'and',
#  'plants',
#  'grow',
#  'there',
#  'the',
#  'leaves',
#  'and',
#  'stems',
#  'of',
#  'which',
#  'are',
#  'so',
#  'pliant',
#  'that',
#  'the',
#  'slightest',
#  'agitation',
#  'of',
#  'the',
#  'water',
#  'causes',
#  'them',
#  'to',
#  'stir',
#  'as',
#  'if',
#  'they',
#  'had',
#  'life']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = ["<START>"] + sentence + ["<END>"]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

co_occurrence['absurd']
# Out:
# defaultdict(int, {})

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['<START>',
#  'fairy',
#  'tales',
#  'of',
#  'hans',
#  'christian',
#  'andersen',
#  'the',
#  'little',
#  'mermaid']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#          <START>  fairy  tales  of  hans  christian  andersen  the  little  \
# <START>        0      1      0   0     0          0         0   55       0
# fairy          1      0      1   0     0          0         0    0       0
# tales          0      1      0   1     0          0         0    0       0
# of             0      0      1   0     1          0         0  105       1
# hans           0      0      0   1     0          2         0    0       0
# ...          ...    ...    ...  ..   ...        ...       ...  ...     ...
# wicked         0      0      0   0     0          0         0    0       0
# tear           0      0      0   0     0          0         0    0       0
# added          0      0      0   0     0          0         0    0       0
# trial          0      0      0   1     0          0         0    0       0
# absurd         0      0      0   0     0          0         0    0       0
#
#          mermaid  ...  room  conduct  count  less  naughty  wicked  tear  \
# <START>        0  ...     0        0      0     0        0       0     0
# fairy          0  ...     0        0      0     0        0       0     0
# tales          0  ...     0        0      0     0        0       0     0
# of             0  ...     0        0      0     1        0       0     0
# hans           0  ...     0        0      0     0        0       0     0
# ...          ...  ...   ...      ...    ...   ...      ...     ...   ...
# wicked         0  ...     0        0      0     0        0       0     0
# tear           0  ...     0        0      0     0        0       0     0
# added          0  ...     0        0      0     0        0       0     0
# trial          0  ...     0        0      0     0        0       0     0
# absurd         0  ...     0        0      0     0        0       0     0
#
#          added  trial  absurd
# <START>      0      0       0
# fairy        0      0       0
# tales        0      0       0
# of           0      1       0
# hans         0      0       0
# ...        ...    ...     ...
# wicked       0      0       0
# tear         0      0       0
# added        0      0       0
# trial        0      0       0
# absurd       0      0       0
#
# [1595 rows x 1595 columns]
